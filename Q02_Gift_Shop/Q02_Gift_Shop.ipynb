# %%
puzzle = open('puzzle.txt', 'r').read()
example = open('example.txt', 'r').read()

# %%
def isValid(num):
    max_repeat_length = len(str(num)) // 2

    for seq_length in range(max_repeat_length):

    return max_repeat_length

isValid(123456)
# Out:
# 3

# %%
input = example.split(',')
input
# Out:
# ['11-22',
#  '95-115',
#  '998-1012',
#  '1188511880-1188511890',
#  '222220-222224',
#  '1698522-1698528',
#  '446443-446449',
#  '38593856-38593862',
#  '565653-565659',
#  '824824821-824824827',
#  '2121212118-2121212124']
